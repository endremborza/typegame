# %%
a = [1, "foo", 0.3]
ALTERNATES = [a[0],a[2], a]
a[1]
# Out:
# 'foo'

# %%
a = [1, "foo", 0.3]
b = [4, 5, 6]
ALTERNATES = [a[0], a[2], a[1]]
a
# Out:
# [1, 'foo', 0.3]

# %%
a = [1, "foo", 0.3]
b = [4, 5, 6]
ALTERNATES = [a[0], a[2], a[1]]
a + b
# Out:
# [1, 'foo', 0.3, 4, 5, 6]

# %%
a = [1, "foo", 0.3]
b = [4, 5, 6]
ALTERNATES = [a[0], a[2], a[1]]
a - b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-42a4bf14abf4> in <module>
#       2 b = [4, 5, 6]
#       3 ALTERNATES = [a[0], a[2], a[1]]
# ----> 4 a - b
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
a = 'A'
for x in ['1', '2', '3']:
    a = a + x
ALTERNATES = [1, 1.0]
a
# Out:
# 'A123'

# %%
g = 10
if (g * 3) < (g + 10):
    h = 0
elif g > 10:
    h = 'A'
else:
    h = [1, 2, 3]
ALTERNATES = [0, 'A', 1.0, True]
h
# Out:
# [1, 2, 3]

# %%
g = 'fing'
if g == 'FING':
    t = 0
elif t == 0:
    t = 'A'
ALTERNATES = [0, 'A', 1.0, True]
t

# %%
def fun1(x, y):
    a = y + 1
    return x * a
ALTERNATES = [fun1, 1, 1.0]
fun1('A', 3)
# Out:
# 'AAAA'

# %%
def fun2(a):
    if a < 10:
        return 'jajj'
    else:
        return 3

for g in [1, 11, 9, 13]:
    x = fun2(g)
ALTERNATES = [1, 'A']
x + 10.5

# %%
def fun3(x):
    a = x - 5
y = fun3(10)
ALTERNATES = [1, 1.1]
y

# %%
l = [1, 2, 3.4, 4]
l.append('A')
ALTERNATES = [1, 1.5]
l[4]

# %%
l2 = ['a', 'b', 'c']
b = 10
for e in l2:
    b = b / 2
    if e == 'b':
        x = b < 6
ALTERNATES = [1, 2.0, lambda x: x]
x

# %%
j = 11
def fun10(c):
    return c < j
ALTERNATES = [1, 1.5, lambda x: x]
fun10(3)

# %%
g = 5
c = True
if (10 > g * 10) or c:
    h = 'fing'
elif c:
    h = 10
ALTERNATES = [True, 1, 2.0, 'A']
h

# %%
kukk = 5.5
jakk = 3.5
def fun13(x):
    return x * 3
ALTERNATES = [1, 1.0, lambda x: x]
fun13(kukk - jakk)
# Out:
# 6.0

# %%
def klikk(c):
    if c:
        return 10
    else:
        return c

c = (10 < 15) and (3 > 1)
b = False
ALTERNATES = [10, 1.0, 'A']
klikk(b and c)

# %%
a = 'jujj'
b = 'jajj'
for c in [2, 3, 4]:
    a = (a + b) * c
ALTERNATES = [1, 1.5, False]
a
